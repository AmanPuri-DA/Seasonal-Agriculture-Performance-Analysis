# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('seasonal_agriculture_performance_dataset.csv')

# %%
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %%
df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 3995        865.4               27.3          51.4                 6.3  ...
# 3996        947.5               29.2          85.5                 6.1  ...
# 3997         80.0               35.4          68.5                 8.6  ...
# 3998        475.0               28.2          61.7                 6.4  ...
# 3999        984.3               25.8          77.2                 5.9  ...
#
# ...

# %%
df.shape
# Out:
# (4000, 28)

# %%
Row=df.shape[0]
print("Toatal Row:",Row)
# Out:
# Toatal Row: 4000

# %%
cols=df.shape[1]
print("Total Columns:",cols)
# Out:
# Total Columns: 28

# %%
df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
df.columns
# Out:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares',
#        'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct',
#        'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha',
#        'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(120)

# %%
df.isnull().mean()*100
# Out:
# Farm_ID                          0.0
# State                            0.0
# District                         0.0
# Crop                             0.0
# Season                           0.0
# Farm_Area_Hectares               0.0
# Rainfall_mm                      1.2
# Avg_Temperature_C                0.0
# Humidity_pct                     0.0
# Sunlight_Hours_Day               0.0
# Soil_pH                          0.0
# Soil_Moisture_pct                1.0
# Nitrogen_kg_ha                   0.0
# Phosphorus_kg_ha                 0.0
# Potassium_kg_ha                  0.0
# Irrigation_Method                0.0
# Fertilizer_kg_ha                 0.0
# Pesticide_Litre_ha               0.0
# Seed_Quality_Score               0.0
# Yield_Tonnes_Ha                  0.8
# Production_Tonnes                0.0
# Market_Price_INR_Tonne           0.0
# Total_Cost_INR                   0.0
# Revenue_INR                      0.0
# Profit_INR                       0.0
# ...

# %%
df['Rainfall_mm'].fillna(round(df['Rainfall_mm'].mean()),inplace=True)
# Out:
# C:\Users\amanp\AppData\Local\Temp\ipykernel_8860\525642328.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rainfall_mm'].fillna(round(df['Rainfall_mm'].mean()),inplace=True)

# %%
df.isnull().sum()
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                       0
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %%
df['Soil_Moisture_pct'].fillna(round(df['Soil_Moisture_pct'].mean()),inplace=True)
df['Yield_Tonnes_Ha'].fillna(round(df['Yield_Tonnes_Ha'].mean()),inplace=True)
# Out:
# C:\Users\amanp\AppData\Local\Temp\ipykernel_18700\2724328794.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Soil_Moisture_pct'].fillna(round(df['Soil_Moisture_pct'].mean()),inplace=True)
# C:\Users\amanp\AppData\Local\Temp\ipykernel_18700\2724328794.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  4000.000000         4000.00000   4000.000000
# mean             7.888265   601.150825           26.81890     63.210500
# std              4.223764   287.185807            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   371.575000           23.90000     54.775000
# 50%              7.895000   585.950000           26.90000     63.000000
# 75%             11.650000   831.975000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        4000.000000     4000.000000
# mean             7.323050     6.701010          26.513150      120.250825
# std              1.121186     0.641461           6.679008       31.216452
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
variables = df.select_dtypes(include=['object'])
print('ToTal variable columns:',variables.columns)
print('Total No of Variables cols:',len(variables.columns))
# Out:
# ToTal variable columns: Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Irrigation_Method'], dtype='object')
# Total No of Variables cols: 6

# %%
Numbrical = df.select_dtypes(include=['int64','float64'])
print('Total numbrical columns:',Numbrical.columns)
print('Total NO of Numbrical cols:',len(Numbrical.columns))
# Out:
# Total numbrical columns: Index(['Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C',
#        'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct',
#        'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')
# Total NO of Numbrical cols: 22

# %%
df.hist(bins=15,layout=(6,5),figsize=(15,20))
# Out:
# array([[<Axes: title={'center': 'Farm_Area_Hectares'}>,
#         <Axes: title={'center': 'Rainfall_mm'}>,
#         <Axes: title={'center': 'Avg_Temperature_C'}>,
#         <Axes: title={'center': 'Humidity_pct'}>,
#         <Axes: title={'center': 'Sunlight_Hours_Day'}>],
#        [<Axes: title={'center': 'Soil_pH'}>,
#         <Axes: title={'center': 'Soil_Moisture_pct'}>,
#         <Axes: title={'center': 'Nitrogen_kg_ha'}>,
#         <Axes: title={'center': 'Phosphorus_kg_ha'}>,
#         <Axes: title={'center': 'Potassium_kg_ha'}>],
#        [<Axes: title={'center': 'Fertilizer_kg_ha'}>,
#         <Axes: title={'center': 'Pesticide_Litre_ha'}>,
#         <Axes: title={'center': 'Seed_Quality_Score'}>,
#         <Axes: title={'center': 'Yield_Tonnes_Ha'}>,
#         <Axes: title={'center': 'Production_Tonnes'}>],
#        [<Axes: title={'center': 'Market_Price_INR_Tonne'}>,
#         <Axes: title={'center': 'Total_Cost_INR'}>,
#         <Axes: title={'center': 'Revenue_INR'}>,
# ...

# %%
df.Season.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Season'>

# %%
df.Season.value_counts(normalize=True) * 100
# Out:
# Season
# Kharif    44.475
# Rabi      40.675
# Zaid      14.850
# Name: proportion, dtype: float64

# %%
df.Season.value_counts()
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
df.Crop.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Crop'>

# %%
df.Irrigation_Method.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Irrigation_Method'>

# %%
df.Irrigation_Method.value_counts()
# Out:
# Irrigation_Method
# Flood        1310
# Rainfed      1041
# Drip          915
# Sprinkler     734
# Name: count, dtype: int64

# %%
df.describe(include={'object':'State'})
# Out:
#         Farm_ID           State  District  Crop  Season Irrigation_Method
# count      4000            4000      4000  4000    4000              4000
# unique     4000               8        10     8       3                 4
# top     SF10001  Andhra Pradesh  Ludhiana  Rice  Kharif             Flood
# freq          1             529       427   690    1779              1310

# %%
df.State.unique()
# Out:
# array(['Andhra Pradesh', 'Maharashtra', 'Telangana', 'Karnataka',
#        'Gujarat', 'Tamil Nadu', 'Punjab', 'Madhya Pradesh'], dtype=object)

# %%
df.District.unique()
# Out:
# array(['Rajkot', 'Nalgonda', 'Warangal', 'Indore', 'Ludhiana', 'Raichur',
#        'Guntur', 'Krishna', 'Nashik', 'Erode'], dtype=object)

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Profit_INR', y='Season', data=df, estimator='sum')
plt.title('Total Profit by Season')
plt.xlabel('Total Profit (INR)')
plt.ylabel('Season')
plt.show()

# %%
df.groupby('Season')['Profit_INR'].sum()
# Out:
# Season
# Kharif    318289158
# Rabi      142670768
# Zaid      -14734066
# Name: Profit_INR, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Profit_INR', y='Crop', data=df, estimator='sum')
plt.title('Total Profit by crop')
plt.xlabel('Total Profit (INR)')
plt.ylabel('Crop')
plt.show()

# %%
df.groupby('Crop')['Profit_INR'].sum()
# Out:
# Crop
# Chilli       309361877
# Cotton        63269833
# Groundnut     19019843
# Maize        -46272058
# Pulses        -2102074
# Rice         -70527318
# Sugarcane    249242336
# Wheat        -75766579
# Name: Profit_INR, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Season', y='Yield_Tonnes_Ha', data=df, estimator='mean')
plt.title('Average Yield by Season')
plt.xlabel('Season')
plt.ylabel('Yield_Tonnes_Hac')
plt.show()

# %%
df.groupby('Season')['Yield_Tonnes_Ha'].mean()
# Out:
# Season
# Kharif    5.643973
# Rabi      5.080498
# Zaid      4.665942
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
data = df.groupby('Season')[['Total_Cost_INR','Revenue_INR', 'Profit_INR']].mean()

data.plot(kind='bar', figsize=(8,6))

plt.title('Cost,Revenue,Profit by Season')
plt.xlabel('Season')
plt.ylabel('Amount (INR)')
plt.xticks(rotation=0)
plt.show()

# %%
yield_data = df.groupby(
    ['Irrigation_Method', 'Season']
)['Yield_Tonnes_Ha'].mean().reset_index()

plt.figure(figsize=(8, 6))

sns.barplot(
    data=yield_data,
    x='Irrigation_Method',
    y='Yield_Tonnes_Ha',
    hue='Season'
)

plt.title('Yield by Irrigation Method and Season')
plt.xlabel('Irrigation Method')
plt.ylabel('Average Yield (tonnes/ha)')
plt.legend(title='Season')

plt.tight_layout()
plt.show()

# %%
df.groupby(['Irrigation_Method', 'Season'])['Yield_Tonnes_Ha'].mean()
# Out:
# Irrigation_Method  Season
# Drip               Kharif    7.256296
#                    Rabi      6.208287
#                    Zaid      5.848143
# Flood              Kharif    5.000017
#                    Rabi      5.098904
#                    Zaid      4.031632
# Rainfed            Kharif    5.721193
#                    Rabi      3.939151
#                    Zaid      3.063786
# Sprinkler          Kharif    4.671375
#                    Rabi      5.356609
#                    Zaid      6.172773
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
df.groupby('Season')[['Total_Cost_INR','Revenue_INR', 'Profit_INR']].mean()
# Out:
#         Total_Cost_INR    Revenue_INR     Profit_INR
# Season
# Kharif   531804.408094  710719.055649  178914.647555
# Rabi     513836.578365  601526.048556   87689.470191
# Zaid     543976.728956  519171.904040  -24804.824916

# %%
df.groupby('Season')[['Total_Cost_INR','Revenue_INR', 'Profit_INR']].sum()
# Out:
#         Total_Cost_INR  Revenue_INR  Profit_INR
# Season
# Kharif       946080042   1264369200   318289158
# Rabi         836012113    978682881   142670768
# Zaid         323122177    308388111   -14734066

# %%
data = df.groupby('Crop')[['Total_Cost_INR','Revenue_INR', 'Profit_INR']].sum()

data.plot(kind='bar', figsize=(8,6))

plt.title('Cost,Revenue,Profit by Crop')
plt.xlabel('Crop')
plt.ylabel('Amount (INR)')
plt.xticks(rotation=0)
plt.show()

# %%
df.groupby('Crop')[['Total_Cost_INR','Revenue_INR', 'Profit_INR']].sum()
# Out:
#            Total_Cost_INR  Revenue_INR  Profit_INR
# Crop
# Chilli          216670341    526032218   309361877
# Cotton          261557093    324826926    63269833
# Groundnut       211184808    230204651    19019843
# Maize           298116521    251844463   -46272058
# Pulses          264221144    262119070    -2102074
# Rice            362821847    292294529   -70527318
# Sugarcane       169211599    418453935   249242336
# Wheat           321430979    245664400   -75766579

# %%
df.groupby('Crop')[['Total_Cost_INR','Revenue_INR', 'Profit_INR']].mean()
# Out:
#            Total_Cost_INR   Revenue_INR     Profit_INR
# Crop
# Chilli      525898.885922  1.276777e+06  750878.342233
# Cotton      514876.167323  6.394231e+05  124546.915354
# Groundnut   498077.377358  5.429355e+05   44858.120283
# Maize       541046.317604  4.570680e+05  -83978.326679
# Pulses      532703.919355  5.284659e+05   -4238.052419
# Rice        525828.763768  4.236153e+05 -102213.504348
# Sugarcane   554792.127869  1.371980e+06  817187.986885
# Wheat       523503.223127  4.001049e+05 -123398.337134

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Disease_Pest_Risk_pct', y='Season', data=df, estimator='mean')
plt.title('Disease_Pest_Risk_pct by Season')
plt.xlabel('Disease_Pest_Risk_pct')
plt.ylabel('Season')
plt.show()

# %%
water = df.groupby('Season')['Water_Used_m3'].mean().reset_index()
plt.figure(figsize=(8, 5))
sns.lineplot(data=water, x="Season", y="Water_Used_m3", errorbar=None)
plt.title("Average Water Usage Across Seasons (line Plot)")
plt.xlabel("Season")
plt.ylabel("Average Water Used (m³)")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="Irrigation_Method", y="Yield_Tonnes_Ha", hue="Season")
plt.title("Yield by Irrigation Method and Season")
plt.xlabel("Irrigation Method")
plt.ylabel("Yield (tonnes/ha)")
plt.legend(title="Season")
plt.tight_layout()
plt.show()

# %%
summary = df.groupby(['Irrigation_Method', 'Season'])['Yield_Tonnes_Ha'].agg(
    Count='count',
    Average='mean',
    Median='median',
    Minimum='min',
    Maximum='max'
).round(2)
summary
# Out:
#                           Count  Average  Median  Minimum  Maximum
# Irrigation_Method Season
# Drip              Kharif    405     7.26    2.14      0.3   101.44
#                   Rabi      362     6.21    1.85      0.3    93.13
#                   Zaid      140     5.85    1.52      0.3    64.21
# Flood             Kharif    586     5.00    1.88      0.3    91.46
#                   Rabi      520     5.10    1.59      0.3    91.32
#                   Zaid      190     4.03    1.21      0.3    56.65
# Rainfed           Kharif    461     5.72    1.86      0.3    77.32
#                   Rabi      436     3.94    1.60      0.3    72.54
#                   Zaid      140     3.06    1.46      0.3    46.48
# Sprinkler         Kharif    320     4.67    1.90      0.3    80.36
#                   Rabi      289     5.36    1.67      0.3    84.75
#                   Zaid      119     6.17    1.79      0.3    64.76

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="Farm_Area_Hectares", y="Production_Tonnes", alpha=0.5)
plt.title("Farm Area vs Production")
plt.xlabel("Farm Area (hectares)")
plt.ylabel("Production (tonnes)")
plt.tight_layout()
plt.show()

# %%
df[['Farm_Area_Hectares', 'Production_Tonnes']].describe()
# Out:
#        Farm_Area_Hectares  Production_Tonnes
# count         4000.000000        4000.000000
# mean             7.888265          43.246210
# std              4.223764         126.880521
# min              0.500000           0.150000
# 25%              4.260000           5.020000
# 50%              7.895000          11.770000
# 75%             11.650000          24.355000
# max             15.000000        1424.400000

# %%
plt.figure(figsize=(16, 12))

corr = df.corr(numeric_only=True)

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    linewidths=0.5
)

plt.title("Correlation Matrix of Numerical Variables")
plt.tight_layout()
plt.show()

# %%
corr = df.corr(numeric_only=True)

summary = corr.stack().reset_index()
summary.columns = ['Variable_1', 'Variable_2', 'Correlation']

summary = summary[
    (summary['Variable_1'] != summary['Variable_2'])
].sort_values('Correlation', ascending=False)

summary.head(10)
# Out:
#                         Variable_1                     Variable_2  Correlation
# 352                 Total_Cost_INR             Farm_Area_Hectares     0.962211
# 16              Farm_Area_Hectares                 Total_Cost_INR     0.962211
# 306                Yield_Tonnes_Ha  Water_Efficiency_t_per_1000m3     0.915438
# 453  Water_Efficiency_t_per_1000m3                Yield_Tonnes_Ha     0.915438
# 392                    Revenue_INR                     Profit_INR     0.887331
# 413                     Profit_INR                    Revenue_INR     0.887331
# 300                Yield_Tonnes_Ha              Production_Tonnes     0.885171
# 321              Production_Tonnes                Yield_Tonnes_Ha     0.885171
# 454  Water_Efficiency_t_per_1000m3              Production_Tonnes     0.812143
# 328              Production_Tonnes  Water_Efficiency_t_per_1000m3     0.812143

# %%
season_metrics = df.groupby("Season").agg(
    Records=("Farm_ID", "count"),
    Average_Yield=("Yield_Tonnes_Ha", "mean"),
    Total_Production=("Production_Tonnes", "sum"),
    Average_Profit=("Profit_INR", "mean"),
    Total_Profit=("Profit_INR", "sum"),
    Average_Water_Used=("Water_Used_m3", "mean")
).round(2)

season_metrics
# Out:
#         Records  Average_Yield  Total_Production  Average_Profit  \
# Season
# Kharif     1779           5.64          82387.61       178914.65
# Rabi       1627           5.08          67498.88        87689.47
# Zaid        594           4.67          23098.35       -24804.82
#
#         Total_Profit  Average_Water_Used
# Season
# Kharif     318289158             6102.20
# Rabi       142670768             5846.99
# Zaid       -14734066             6419.89

# %%
crop_season_summary = (
    df.groupby(["Season", "Crop"])
      .agg(
          Average_Yield=("Yield_Tonnes_Ha", "mean"),
          Average_Profit=("Profit_INR", "mean"),
          Average_Water_Efficiency=("Water_Efficiency_t_per_1000m3", "mean")
      )
      .round(2)
      .sort_values(["Season", "Average_Yield"], ascending=[True, False])
)

crop_season_summary
# Out:
#                   Average_Yield  Average_Profit  Average_Water_Efficiency
# Season Crop
# Kharif Sugarcane          53.46      1000790.81                     36.00
#        Maize               2.97       -39332.67                      6.05
#        Rice                2.71       -64903.40                      2.17
#        Wheat               2.26      -105871.87                      4.76
#        Chilli              1.73       954380.42                      3.26
#        Groundnut           1.48       108265.44                      3.58
#        Cotton              1.37       216999.55                      2.13
#        Pulses              1.04        43338.90                      3.35
# Rabi   Sugarcane          43.94       731612.86                     27.92
#        Maize               2.61       -89133.40                      5.46
#        Rice                2.33       -98427.87                      1.84
# ...
